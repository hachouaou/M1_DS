# %%
from math import pi
import matplotlib.pyplot as plt
import numpy as np
from numpy import linalg # sous bibliotheque algebre lineaire
from numpy.linalg import eig #eigenvalue : valeur propre
from numpy.linalg import inv, norm, det
'''
n=100
A=np.random.rand(n,n)
b=np.random.rand(n)
x=linalg.solve(A,b) # solution du syteme lineaire Ax=b
erreur=linalg.norm(np.dot(A,x)-b)
print(erreur)


n=100 # inverse, determinant, norme, ...
A=np.random.rand(n,n)
det(A)
B=inv(A)
C=np.dot(A,B)
print("||AB-I|| = ",norm(C-np.eye(n)))


n=3
A=np.random.rand(n,n)
D, V = eig(A) # Que sont D et V ?
k=2
d,u=D[k],V[:,k]
z=np.dot(A,u)-d*u # z= ??
print(' z = ',norm(z))
r=np.linalg.matrix_rank(A) # rank : rang


X=np.linspace(-1,1,100)
Y=np.sin(4*pi*X)*np.exp(X)
plt.plot(X,Y, '-r')
plt.xlabel('x') ; plt.ylabel('y') ;
plt.grid()
plt.show()

Z=np.cos(4*pi*X)*np.exp(-X)
plt.plot(X,Y, '-.r',X,Z,'-b',markersize=6)
plt.legend(["f(x)", "g(x)"])
plt.title('Afficher un texte ici')
plt.xlabel('x') ; plt.ylabel('y') ;
plt.grid()
plt.show()
'''
#Ligne de niveau
x=np.linspace(-1,1)
y=np.linspace(-1,1)
X, Y = np.meshgrid(x, y)
Z1 = np.exp(X)+X*Y**2-1
Z2 = np.sin(X+Y)+X**2-1
dessin=plt.contour(X, Y, Z1, levels=np.linspace(-1,1,9))
plt.clabel(dessin, fmt= '%.3f', inline = True)
dessin=plt.contour(X, Y, Z2, levels=np.linspace(-1,1,9))
plt.clabel(dessin, fmt= '%.3f', inline = True)
plt.show()

# %%
from math import pi
import matplotlib.pyplot as plt
X=np.linspace(-1,1,100)
Y=np.sin(4*pi*X)*np.exp(X)
plt.plot(X,Y, '-r')
plt.xlabel('x') ; plt.ylabel('y') ;
plt.grid()
plt.show()

# %%
#Champ de vecteur
x= np.linspace(-5, 5,20)
y= np.linspace(-5, 5,20)
X,Y=np.meshgrid(x,y)
U=X+Y
V=X-Y
plt.quiver(X,Y,U,V)
plt.show()

# %%
#Ajout d'un BB

import numpy as np
import matplotlib.pyplot as plt
N = 200
t = np.linspace(0, 20, N)
d = 20 * np.exp(-0.5*t)
sigma = 0.5
d_bruit = d + sigma * np.random.randn(N)
# que represente np.random.randn(N) ?
4
plt.figure()
plt.plot(t, d_bruit, "o", label = "donnees bruitees")
plt.plot(t, d, "-r", label = "donnees simulees")
plt.xlabel("t") ; plt.ylabel("donnees") ;
plt.legend() # que remarquez vous quand N varie ? et sigma ?
plt.show()
# Out:
# [2.00000000e+01 1.90198090e+01 1.80876568e+01 1.72011889e+01
#  1.63581664e+01 1.55564601e+01 1.47940450e+01 1.40689956e+01
#  1.33794804e+01 1.27237582e+01 1.21001725e+01 1.15071485e+01
#  1.09431884e+01 1.04068677e+01 9.89683180e+00 9.41179255e+00
#  8.95052485e+00 8.51186367e+00 8.09470108e+00 7.69798344e+00
#  7.32070876e+00 6.96192413e+00 6.62072338e+00 6.29624472e+00
#  5.98766861e+00 5.69421568e+00 5.41514474e+00 5.14975095e+00
#  4.89736398e+00 4.65734639e+00 4.42909195e+00 4.21202415e+00
