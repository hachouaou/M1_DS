# %% [markdown]
# # <font color=darkcyan> Multivariate linear regression - Lasso </font>

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib import colors 
from sklearn.metrics import mean_squared_error

# %% [markdown]
# It is assumed that for all $1\leqslant i \leqslant n$,
#
# $$
# Y_i = X^\top_i \beta_{\star} + \varepsilon_i\,,
# $$
#
# where the $(\varepsilon_i)_{1\leqslant i\leqslant n}$ are i.i.d. random variables in $\mathbb{R}$, $X_i\in\mathbb{R}^d$ and $\beta_{\star}$ is an unknown vector in $\mathbb{R}^d$. Let $Y\in\mathbb{R}^n$ (resp. $\varepsilon\in\mathbb{R}^n$)  be the random vector such that  for all $1\leqslant i \leqslant n$, the $i$-th component of $Y$ (resp. $\varepsilon$) is $Y_i$ (resp. $\varepsilon_i$) and $X\in\mathbb{R}^{n\times d}$ the matrix with line $i$ equal to $X^\top_i$. The model is then written
#
# $$
# Y = X \beta_{\star} + \varepsilon\,.
# $$
#
# In this section, it is assumed that $\mathbb{E}[\varepsilon] = 0$ and $\mathbb{E}[\varepsilon \varepsilon^\top] = \sigma_{\star}^2 I_n$. The Lasso estimate of $\beta_{\star}$ is defined as a solution to
#
# $$
# \widehat \beta_n\in  \mathrm{argmin}_{\beta\in\mathbb{R}^d}\,\left( n^{-1}\|Y - X\beta\|_2^2 + \lambda \|\beta\|_1\right)\,,
# $$
#
# where $\lambda>0$.

# %% [markdown]
# <font color=darkred> Explain the coordinate-wise optimization procedure </font>

# %% [markdown]
# #### Import data

# %%
import pandas as pd

# %% [markdown]
# Data frames can be imported using pandas. This provides two-dimensional and heterogeneous tabular data.
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.html

# %% [markdown]
# <font color=darkred>
# Import data in the file BRinf using ``read_csv``, display the first rows with ``head`` and the shape of the dataframe using ``shape``.
# </font>

# %%
# In this section, multivariate linear regression is used to predic the Brazilian inflation based on
# many observed variables, see https://github.com/gabrielrvsc/HDeconometrics/
df = pd.read_csv('BRinf.csv')
df.head()
# Out:
#    Unnamed: 0  Brazil CPI IPCA MoM  FGV Brazil General Prices IGP-  \
# 0  2003-01-31                 2.25                            2.33
# 1  2003-02-28                 1.57                            2.28
# 2  2003-03-31                 1.23                            1.53
# 3  2003-04-30                 0.97                            0.92
# 4  2003-05-31                 0.61                           -0.26
#
#    FGV Brazil General Prices IGP-.1  FGV Brazil General Prices IGP-.2  \
# 0                              2.17                             5.816
# 1                              1.59                             4.351
# 2                              1.66                             4.593
# 3                              0.41                             1.173
# 4                             -0.67                            -1.860
#
#    FGV Brazil General Prices IGP-.3  Brazil CPI IPCA Median Market  \
# 0                              2.29                          11.56
# 1                              2.42                          10.95
# 2                              1.58                           9.58
# 3                              1.24                           8.88
# 4                              0.02                           8.22
#
#    Brazil Total Electricity Consu  Brazil Industrial Electricity  \
# 0                         25422.0                           -359
# 1                         25163.0                           -303
# 2                         24960.0                            115
# 3                         25284.0                             93
# 4                         24785.0                            285
#
#    BofA Merrill Lynch Economic Co  ...  X5t.12  X5t.13   fmed2  fmean  fmean2  \
# 0                           -1.47  ...    0.80    0.68  4.0000   1.96  3.8416
# 1                           -1.21  ...    0.68    0.48  2.5600   1.60  2.5600
# 2                           -0.35  ...    0.55    0.50  0.8836   0.93  0.8649
# 3                           -0.15  ...    0.45    0.78  1.0000   0.97  0.9409
# 4                           -0.47  ...    0.60    0.43  0.2500   0.50  0.2500
#
#     fdp  lfmed2  lfmean  lfmean2  lfdp
# 0  0.18  1.3225    1.15   1.3225  0.24
# 1  0.26  0.7569    0.91   0.8281  0.27
# 2  0.13  0.4900    0.73   0.5329  0.17
# 3  0.14  0.2500    0.52   0.2704  0.18
# 4  0.10  0.3025    0.55   0.3025  0.15
#
# [5 rows x 93 columns]

# %%
# number of observations, number of variables
df.shape
#enlever variable date
df = df.iloc[: , 1:]

# %% [markdown]
# <font color=darkred>
# Use the ``StandardScaler`` of sklearn to preprocess the input variables.
# </font>

# %% [markdown]
# ``StandardScaler`` standardizes the input variables by removing the mean and scaling to unit variance.
# We will not analyze closely standardization in this course. However, it is often very useful (even mandatory in some cases) for the stability of learning procedures.
# https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
# Out:
# (156, 92)

# %% [markdown]
# <font color=darkred>
# Build two datasets.
#     ``X_train`` and ``Y_train`` contain the first 140 input data and observations. ``X_test`` and ``Y_test`` contain the remaining input data and observations. We train a linear regression model using ``X_train`` and ``Y_train`` and we assess the performance of the model using ``X_test`` and ``Y_test``.
# </font>

# %% [markdown]
# https://pandas.pydata.org/docs/reference/frame.html

# %%
nombre_train =  140


sc = scaler.fit(df.iloc[:nombre_train, 1:])
X = sc.transform(df.iloc[:, 1:])
X = pd.DataFrame(X)

X_train, Y_train = X.iloc[:nombre_train, 1:], X.iloc[:nombre_train, 0]
X_test, Y_test = X.iloc[nombre_train:, 1:], X.iloc[nombre_train:, 0]

print(f"Y_train = {Y_train.shape}, \n Y_test = {Y_test.shape}, \n X_train = {X_train.shape}, \n X_test = {X_test.shape}")

# Convert DataFrame to NumPy arrays
X_train = X_train.to_numpy()
Y_train = Y_train.to_numpy()
X_test = X_test.to_numpy()
Y_test = Y_test.to_numpy()
# Out:
# Y_train = (140,),
#  Y_test = (16,),
#  X_train = (140, 90),
#  X_test = (16, 90)

# %% [markdown]
# #### Lasso Regression from scractch

# %% [markdown]
# <font color=darkred>
# Write a ``threshold_function`` function with arguments a real number ``z`` and a positive number ``$\alpha$`` which returns
# $$
# \begin{cases}
# z+\alpha & \text{if } z<-\alpha, \\
# z-\alpha & \text{if } z>\alpha, \\
# 0 & \text{otherwise}. \\
# \end{cases}
# $$
# </font>

# %%
def threshold_function(z, alpha):
    if z < -alpha:
        return (z + alpha)
    elif z > alpha:
        return (z - alpha)
    else:
        return 0

# %% [markdown]
# <font color=darkred>
#     Write a coordinate_descent_lasso function with arguments an initial estimate $\beta$, the data X and y, a penalty parameter $\alpha$ and a number of iterations n_iter. The function returns the parameter estimate after n_iter iterations of the coordinate-wise optimization procedure.
#
#
#
# </font>

# %% [markdown]
# To make things simpler, you can write the function with $\alpha = \lambda n /2$ in the mathematical derivation above.

# %%
def coordinate_descent_lasso_random(beta, X, y, lambda_truc , n_iter, liste_iter):
    n, d = X.shape
    liste_beta = []
    n_iter = int(n_iter) #CORRECTION : on calcule la norme au carré de chaque colonne de X

    for _ in range(n_iter + 1):
        # Choisir aléatoirement une coordonnée j dans {0, ..., d-1}
        j = np.random.randint(d)
        
        #Calcul B_j
        X_j = X[:, j]
        residual = y - X.dot(beta) + beta[j] * X_j
        v_j = (X_j @ residual)

        # Mettre à jour beta[j]

        #CORRECTION~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

        beta[j] = threshold_function(v_j, lambda_truc/2) / n #CORRECTION / on diviste par la norme au carré de la colonne j
        
    
        #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~


        #Enregistrer les valeurs de beta pour certaines itérations
        if _ in liste_iter:
            liste_beta.append(beta.copy())

 
    return np.array(liste_beta)

# %% [markdown]
# <font color=darkred>
#     Run the algorithm with several values of $\alpha$ using X_train and Y_train and display the number of zero coeficients of the parameter estimate and the MSE obtained on the test set.
#     </font>

# %%
liste_lambdas =  [0.001, 0.002, 0.005, 0.01, 0.02, 0.05, 0.1, 0.2, 0.5, 1.0, 2.0]
liste_iter = np.arange(500, 10101, 200)
n_iter = liste_iter[-1]

# %%
#MES RESULTATS

results = []

#Pour les graphiques de fin
my_liste_beta = []
my_liste_num_zero_coefs =[]
my_liste_mse = []
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

for lambda_truc in liste_lambdas :
        beta_initial = np.random.randn(X_train.shape[1])

        #Pour les graphiques de fin
        liste_beta_hat = coordinate_descent_lasso_random(beta_initial, X_train, Y_train, lambda_truc, n_iter, liste_iter)
        my_liste_beta.append(liste_beta_hat[-1])
        my_liste_num_zero_coefs.append(np.sum(liste_beta_hat[-1] == 0))
        my_liste_mse.append(mean_squared_error(Y_test, X_test @ liste_beta_hat[-1]))
        #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~	

        # Récupérer les résultats pour chaque itération
        for beta_hat, n_iter in zip(liste_beta_hat, liste_iter):
            num_zero_coefs = np.sum(beta_hat == 0) # Nombre de zéro coefficients
            beta_hat_norm = np.linalg.norm(beta_hat) # Norme de béta_hat
            Y_pred = X_test @ beta_hat # Prédiction sur le test set
            mse = mean_squared_error(Y_test, Y_pred) 
            results.append((lambda_truc, n_iter, num_zero_coefs, mse, beta_hat_norm))

results = np.array(results)

# %%
for lambda_truc in liste_lambdas :

    print(f"\n~~~~~~~~~~~~~~~~~~~~\nPour lambda = {lambda_truc} \n")
    results_lambda = [result for result in results if result[0] == lambda_truc]

    for lambda_truc, n_iter, num_zero_coefs, mse, beta_hat_norm in results_lambda:
        print(f"Avec {n_iter} itérations, il y a {num_zero_coefs} coeff de béta mis à 0, et le MSE= {mse}")
        print(f"Norme de béta_hat = {beta_hat_norm} \n")
# Out:
# ~~~~~~~~~~~~~~~~~~~~
# Pour lambda = 0.001
#
# Avec 500.0 itérations, il y a 0.0 coeff de béta mis à 0, et le MSE= 3.9516890765954913
# Norme de béta_hat = 7.518824175576388
#
# Avec 700.0 itérations, il y a 0.0 coeff de béta mis à 0, et le MSE= 3.6836628211895306
# Norme de béta_hat = 7.17648421426731
#
# Avec 900.0 itérations, il y a 0.0 coeff de béta mis à 0, et le MSE= 3.7259597624486007
# Norme de béta_hat = 7.058014998796458
#
# Avec 1100.0 itérations, il y a 0.0 coeff de béta mis à 0, et le MSE= 4.364796547487135
# Norme de béta_hat = 6.8953587823992715
#
# Avec 1300.0 itérations, il y a 0.0 coeff de béta mis à 0, et le MSE= 3.86592077280895
# Norme de béta_hat = 6.796700597453962
#
# Avec 1500.0 itérations, il y a 0.0 coeff de béta mis à 0, et le MSE= 3.5916642726133468
# Norme de béta_hat = 6.674236874593801
#
# Avec 1700.0 itérations, il y a 0.0 coeff de béta mis à 0, et le MSE= 3.7620197273335094
# Norme de béta_hat = 6.595107547498905
#
# Avec 1900.0 itérations, il y a 0.0 coeff de béta mis à 0, et le MSE= 3.8433632917388745
# Norme de béta_hat = 6.515516533507148
#
# Avec 2100.0 itérations, il y a 0.0 coeff de béta mis à 0, et le MSE= 3.9092591530468725
# Norme de béta_hat = 6.4608180751871
#
# Avec 2300.0 itérations, il y a 0.0 coeff de béta mis à 0, et le MSE= 3.6960663683945083
# Norme de béta_hat = 6.383063323995872
#
# Avec 2500.0 itérations, il y a 0.0 coeff de béta mis à 0, et le MSE= 3.752914846529494
# Norme de béta_hat = 6.289215523747002
#
# Avec 2700.0 itérations, il y a 0.0 coeff de béta mis à 0, et le MSE= 3.5976330097344196
# Norme de béta_hat = 6.227002668056418
#
# Avec 2900.0 itérations, il y a 0.0 coeff de béta mis à 0, et le MSE= 3.4068694122611127
# Norme de béta_hat = 6.184861313364382
#
# Avec 3100.0 itérations, il y a 0.0 coeff de béta mis à 0, et le MSE= 3.143147738636955
# Norme de béta_hat = 6.123982420082236
#
# Avec 3300.0 itérations, il y a 0.0 coeff de béta mis à 0, et le MSE= 2.935508781319428
# Norme de béta_hat = 6.065463145046065
#
# Avec 3500.0 itérations, il y a 0.0 coeff de béta mis à 0, et le MSE= 3.0417283114744516
# Norme de béta_hat = 6.016255311249774
#
# Avec 3700.0 itérations, il y a 0.0 coeff de béta mis à 0, et le MSE= 3.1420357895467825
# Norme de béta_hat = 5.963597324034876
#
# Avec 3900.0 itérations, il y a 0.0 coeff de béta mis à 0, et le MSE= 3
.0 itérations, il y a 0.0 coeff de béta mis à 0, et le MSE= 1.5761778121501795
# Norme de béta_hat = 5.949750243927089
#
# Avec 9100.0 itérations, il y a 0.0 coeff de béta mis à 0, et le MSE= 1.5463599306372695
# Norme de béta_hat = 5.913129339652986
#
# Avec 9300.0 itérations, il y a 0.0 coeff de béta mis à 0, et le MSE= 1.5546182161934707
# Norme de béta_hat = 5.889024583368993
#
# Avec 9500.0 itérations, il y a 0.0 coeff de béta mis à 0, et le MSE= 1.546451916926878
# Norme de béta_hat = 5.867179794058906
#
# Avec 9700.0 itérations, il y a 0.0 coeff de béta mis à 0, et le MSE= 1.509366440954887
# Norme de béta_hat = 5.854814165818392
#
# Avec 9900.0 itérations, il y a 0.0 coeff de béta mis à 0, et le MSE= 1.46833356061726
# Norme de béta_hat = 5.822236592236586
#
# Avec 10100.0 itérations, il y a 0.0 coeff de béta mis à 0, et le MSE= 1.4216685526469304
# Norme de béta_hat = 5.786455913667484
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Pour lambda = 0.2
#
# Avec 500.0 itérations, il y a 0.0 coeff de béta mis à 0, et le MSE= 28.68390320849848
# Norme de béta_hat = 6.781137399048614
#
# Avec 700.0 itérations, il y a 0.0 coeff de béta mis à 0, et le MSE= 27.989866883604066
# Norme de béta_hat = 5.96416314896228
#
# Avec 900.0 itérations, il y a 0.0 coeff de béta mis à 0, et le MSE= 19.366923719441157
# Norme de béta_hat = 5.52083670766256
#
# Avec 1100.0 itérations, il y a 0.0 coeff de béta mis à 0, et le MSE= 18.14051427001776
# Norme de béta_hat = 5.31498939353988
#
# Avec 1300.0 itérations, il y a 0.0 coeff de béta mis à 0, et le MSE= 16.081844830995564
# Norme de béta_hat = 5.093795678308808
#
# Avec 1500.0 itérations, il y a 0.0 coeff de béta mis à 0, et le MSE= 14.307184807800791
# Norme de béta_hat = 4.925886069645349
#
# Avec 1700.0 itérations, il y a 0.0 coeff de béta mis à 0, et le MSE= 12.377300363846462
# Norme de béta_hat = 4.710762314154848
#
# Avec 1900.0 itérations, il y a 0.0 coeff de béta mis à 0, et le MSE= 11.665600238443183
# Norme de béta_hat = 4.607785729279436
#
# Avec 2100.0 itérations, il y a 0.0 coeff de béta mis à 0, et le MSE= 10.277707717898073
# Norme de béta_hat = 4.526073507195943
#
# Avec 2300.0 itérations, il y a 0.0 coeff de béta mis à 0, et le MSE= 9.737910237791116
# Norme de béta_hat = 4.439114376963394
#
# Avec 2500.0 itérations, il y a 1.0 coeff de béta mis à 0, et le MSE= 9.534376052362454
# Norme de béta_hat = 4.351067411267812
#
# Avec 2700.0 itérations, il y a 1.0 coeff de béta mis à 0, et le MSE= 8.36594780438142
# Norme de béta_hat = 4.28707463043799
#
# Avec 2900.0 itérations, il y a 0.0 coeff de béta mis à 0, et le MSE= 7.411230169948249
# Norme de béta_hat = 4.215437873256104
#
# Avec 3100.0 itérations, il y a 0.0 coeff de béta mis à 0, et le MSE= 6.378709965440627
# Norme de béta_hat = 4.158383788835926
#
# Avec 3300.0 itérations, il y a 0.0 coeff de béta mis à 0, et le MSE= 6.471952032524581
# Norme de béta_hat = 4.10963130010885
#
# Avec 3500.0 itérations, il y a 0.0 coeff de béta mis à 0, et le MSE= 5.560302056300282
# Norme de béta_hat = 4.040521752285268
#
# Avec 3700.0 itérations, il y a 1.0 coeff de béta mis à 0, et le MSE= 5.079690680711334
# Norme de béta_hat = 3.993179651192698
#
# Avec 3900.0 itérations, il y a 0.0 coeff de béta mis à 0, et le MSE= 5.191252178629441
# Norme de béta_hat = 3.9501659436489205
#
# Avec 4100.0 itérations, il y a 1.0 coeff de béta mis à 0, et le MSE= 4.728473139754037
# Norme de béta_hat = 3.907214378389025
#
# Avec 4300.0 itérations, il y a 0.0 coeff de béta mis à 0, et le MSE= 4.524220037419736
# Norme de béta_hat = 3.8567559087726067
#
# Avec 4500.0 itérations, il y a 1.0 coeff de béta mis à 0, et le MSE= 4.177076925137357
# Norme de béta_hat = 3.8350641272498085
#
# Avec 4700.0 itérations, il y a 0.0 coeff de béta mis à 0, et le MSE= 3.7704785325062886
# Norme de béta_hat = 3.7933655047699477
#
# Avec 4900.0 itérations, il y a 0.0 coeff de béta mis à 0, et le MSE= 3.6465922400481356
# Norme de béta_hat = 3.756489840776633
#
# Avec 5100.0 itérations, il y a 0.0 coeff de béta mis à 0, et le MSE= 3.691187614045293
# Norme de béta_hat = 3.7272652111272273
#
# Avec 5300.0 itérations, il y a 0.0 coeff de béta mis à 0, et le MSE= 3.5978932572204765
# Norme de béta_hat = 3.6843719189341555
#
# Avec 5500.0 itérations, il y a 0.0 coeff de béta mis à 0, et le MSE= 3.2942014427650133
# Norme de béta_hat = 3.648046713071082
#
# Avec 5700.0 itérations, il y a 1.0 coeff de béta mis à 0, et le MSE= 3.272297772908603
# Norme de béta_hat = 3.6203323018784097
#
# Avec 5900.0 itérations, il y a 0.0 coeff de béta mis à 0, et le MSE= 3.1529982339169833
# Norme de béta_hat = 3.5918065989308468
#
# Avec 6100.0 itérations, il y a 1.0 coeff de béta mis à 0, et le MSE= 2.9749085961398722
# Norme de béta_hat = 3.5630995457374612
#
# Avec 6300.0 itérations, il y a 2.0 coeff de béta mis à 0, et le MSE= 2.7398960095194727
# Norme de béta_hat = 3.539271014460806
#
# Avec 6500.0 itérations, il y a 1.0 coeff de béta mis à 0, et le MSE= 2.674152486256448
# ...
# Norme de béta_hat = 5.301733431185309
#
# Avec 5300.0 itérations, il y a 0.0 coeff de béta mis à 0, et le MSE= 3.5267377334584413
# Norme de béta_hat = 5.250905402808645
#
# Avec 5500.0 itérations, il y a 0.0 coeff de béta mis à 0, et le MSE= 3.692857766085825
# Norme de béta_hat = 5.1818906654376224
#
# Avec 5700.0 itérations, il y a 0.0 coeff de béta mis à 0, et le MSE= 3.5341387291191055
# Norme de béta_hat = 5.130944048645669
#
# Avec 5900.0 itérations, il y a 1.0 coeff de béta mis à 0, et le MSE= 3.24114660177978
# Norme de béta_hat = 5.063362157950787
#
# Avec 6100.0 itérations, il y a 3.0 coeff de béta mis à 0, et le MSE= 3.019866829233005
# Norme de béta_hat = 5.006668777951367
#
# Avec 6300.0 itérations, il y a 2.0 coeff de béta mis à 0, et le MSE= 2.9654587006959545
# Norme de béta_hat = 4.941001170431994
#
# Avec 6500.0 itérations, il y a 1.0 coeff de béta mis à 0, et le MSE= 2.7389026653390705
# Norme de béta_hat = 4.886925847699128
#
# Avec 6700.0 itérations, il y a 0.0 coeff de béta mis à 0, et le MSE= 2.7316364578037637
# Norme de béta_hat = 4.846268480273322
#
# Avec 6900.0 itérations, il y a 0.0 coeff de béta mis à 0, et le MSE= 2.622335324201421
# Norme de béta_hat = 4.80078234606579
#
# Avec 7100.0 itérations, il y a 2.0 coeff de béta mis à 0, et le MSE= 2.568922021515378
# Norme de béta_hat = 4.761254719044192
#
# Avec 7300.0 itérations, il y a 1.0 coeff de béta mis à 0, et le MSE= 2.48148244937615
# Norme de béta_hat = 4.717816736364501
#
# Avec 7500.0 itérations, il y a 1.0 coeff de béta mis à 0, et le MSE= 2.3586933638955188
# Norme de béta_hat = 4.669111455458758
#
# Avec 7700.0 itérations, il y a 1.0 coeff de béta mis à 0, et le MSE= 2.272176018102516
# Norme de béta_hat = 4.629734135791716
#
# Avec 7900.0 itérations, il y a 2.0 coeff de béta mis à 0, et le MSE= 2.2428815599109484
# Norme de béta_hat = 4.591286287218558
#
# Avec 8100.0 itérations, il y a 2.0 coeff de béta mis à 0, et le MSE= 2.1849286655429627
# Norme de béta_hat = 4.556457808190979
#
# Avec 8300.0 itérations, il y a 2.0 coeff de béta mis à 0, et le MSE= 2.034348328443248
# Norme de béta_hat = 4.513947280317122
#
# Avec 8500.0 itérations, il y a 3.0 coeff de béta mis à 0, et le MSE= 1.9966587234831636
# Norme de béta_hat = 4.470559470665823
#
# Avec 8700.0 itérations, il y a 2.0 coeff de béta mis à 0, et le MSE= 1.916066005402938
# Norme de béta_hat = 4.4329161385314375
#
# Avec 8900.0 itérations, il y a 1.0 coeff de béta mis à 0, et le MSE= 1.9864725068437945
# Norme de béta_hat = 4.394129862281621
#
# Avec 9100.0 itérations, il y a 0.0 coeff de béta mis à 0, et le MSE= 1.8763389601763583
# Norme de béta_hat = 4.349153623146
#
# Avec 9300.0 itérations, il y a 1.0 coeff de béta mis à 0, et le MSE= 1.7375730321786944
# Norme de béta_hat = 4.305597294820614
#
# Avec 9500.0 itérations, il y a 0.0 coeff de béta mis à 0, et le MSE= 1.667615849403637
# Norme de béta_hat = 4.2734809016585285
#
# Avec 9700.0 itérations, il y a 1.0 coeff de béta mis à 0, et le MSE= 1.602011674823826
# Norme de béta_hat = 4.244869598457213
#
# Avec 9900.0 itérations, il y a 2.0 coeff de béta mis à 0, et le MSE= 1.53167512425909
# Norme de béta_hat = 4.207934560317835
#
# Avec 10100.0 itérations, il y a 2.0 coeff de béta mis à 0, et le MSE= 1.4636580536300916
# Norme de béta_hat = 4.181151763140507
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Pour lambda = 1.0
#
# Avec 500.0 itérations, il y a 1.0 coeff de béta mis à 0, et le MSE= 9.880193388090095
# Norme de béta_hat = 7.210232474640547
#
# Avec 700.0 itérations, il y a 0.0 coeff de béta mis à 0, et le MSE= 6.936746911193199
# Norme de béta_hat = 6.759698852981698
#
# Avec 900.0 itérations, il y a 1.0 coeff de béta mis à 0, et le MSE= 5.589212232194599
# Norme de béta_hat = 6.320395011346941
#
# Avec 1100.0 itérations, il y a 1.0 coeff de béta mis à 0, et le MSE= 5.883069658220702
# Norme de béta_hat = 6.055754055540983
#
# Avec 1300.0 itérations, il y a 4.0 coeff de béta mis à 0, et le MSE= 4.492483909532247
# Norme de béta_hat = 5.843780300441451
#
# Avec 1500.0 itérations, il y a 3.0 coeff de béta mis à 0, et le MSE= 3.9302122803714754
# Norme de béta_hat = 5.650122530136348
#
# Avec 1700.0 itérations, il y a 0.0 coeff de béta mis à 0, et le MSE= 3.0915695670918852
# Norme de béta_hat = 5.432006131582827
#
# Avec 1900.0 itérations, il y a 2.0 coeff de béta mis à 0, et le MSE= 2.7703624018110853
# Norme de béta_hat = 5.198941980993083
#
# Avec 2100.0 itérations, il y a 2.0 coeff de béta mis à 0, et le MSE= 2.4522007487497293
# Norme de béta_hat = 5.080123542245387
#
# Avec 2300.0 itérations, il y a 1.0 coeff de béta mis à 0, et le MSE= 2.3124049865740766
# Norme de béta_hat = 4.911363582236537
#
# Avec 2500.0 itérations, il y a 5.0 coeff de béta mis à 0, et le MSE= 2.189320729735897
# Norme de béta_hat = 4.775270037326118
#
# Avec 2700.0 itérations, il y a 2.0 coeff de béta mis à 0, et le MSE= 2.040206410635261
# Norme de béta_hat = 4.618616624111482
#
# Avec 2900.0 itérations, il y a 2.0 coeff de béta mis à 0, et le MSE= 1.6787009020152315
# Norme de béta_hat = 4.4872744650334955
#
# Avec 3100.0 itérations, il y a 4.0 coeff de béta mis à 0, et le MSE= 1.5148455840013817
# Norme de béta_hat = 4.35846721786682
#
# Avec 3300.0 itérations, il y a 3.0 coeff de béta mis à 0, et le MSE= 1.42403254991352
# Norme de béta_hat = 4.240288892834245
#
# Avec 3500.0 itérations, il y a 3.0 coeff de béta mis à 0, et le MSE= 1.2504499308711967
# Norme de béta_hat = 4.121858071048136
#
# Avec 3700.0 itérations, il y a 3.0 coeff de béta mis à 0, et le MSE= 1.2097050478571596
# Norme de béta_hat = 4.042883775757813
#
# Avec 3900.0 itérations, il y a 4.0 coeff de béta mis à 0, et le MSE= 1.0435840829736232
# Norme de béta_hat = 3.9397834752844583
#
# Avec 4100.0 itérations, il y a 1.0 coeff de béta mis à 0, et le MSE= 0.9727487916551234
# Norme de béta_hat = 3.849272187184071
#
# Avec 4300.0 itérations, il y a 4.0 coeff de béta mis à 0, et le MSE= 0.9451102590742899
# Norme de béta_hat = 3.800895942380276
#
# Avec 4500.0 itérations, il y a 4.0 coeff de béta mis à 0, et le MSE= 0.8471973119635219
# Norme de béta_hat = 3.7063682315504067
#
# Avec 4700.0 itérations, il y a 6.0 coeff de béta mis à 0, et le MSE= 0.7918737941225792
# Norme de béta_hat = 3.643201664090349
#
# Avec 4900.0 itérations, il y a 5.0 coeff de béta mis à 0, et le MSE= 0.6960832994667697
# Norme de béta_hat = 3.592132744939647
#
# Avec 5100.0 itérations, il y a 5.0 coeff de béta mis à 0, et le MSE= 0.6122071067857775
# Norme de béta_hat = 3.5184058790213135
#
# Avec 5300.0 itérations, il y a 6.0 coeff de béta mis à 0, et le MSE= 0.5461696506866305
# Norme de béta_hat = 3.434914173082092
#
# Avec 5500.0 itérations, il y a 8.0 coeff de béta mis à 0, et le MSE= 0.49218151275849764
# Norme de béta_hat = 3.327329609411723
#
# Avec 5700.0 itérations, il y a 9.0 coeff de béta mis à 0, et le MSE= 0.4670295091573993
# Norme de béta_hat = 3.2204378008024728
#
# Avec 5900.0 itérations, il y a 7.0 coeff de béta mis à 0, et le MSE= 0.42475331527787963
# Norme de béta_hat = 3.1393320639836624
#
# Avec 6100.0 itérations, il y a 6.0 coeff de béta mis à 0, et le MSE= 0.4020849361324599
# Norme de béta_hat = 3.07052403324917
#
# Avec 6300.0 itérations, il y a 5.0 coeff de béta mis à 0, et le MSE= 0.3837468370265019
# Norme de béta_hat = 3.0120435326167767
#
# Avec 6500.0 itérations, il y a 8.0 coeff de béta mis à 0, et le MSE= 0.33981235436008317
# Norme de béta_hat = 2.922234167530249
#
# Avec 6700.0 itérations, il y a 10.0 coeff de béta mis à 0, et le MSE= 0.3062844776320896
# Norme de béta_hat = 2.843817580646323
#
# Avec 6900.0 itérations, il y a 14.0 coeff de béta mis à 0, et le MSE= 0.2993821035955416
# Norme de béta_hat = 2.7922634477543764
#
# Avec 7100.0 itérations, il y a 9.0 coeff de béta mis à 0, et le MSE= 0.2893460254466088
# Norme de béta_hat = 2.727728424199432
#
# Avec 7300.0 itérations, il y a 8.0 coeff de béta mis à 0, et le MSE= 0.284715396805068
# Norme de béta_hat = 2.6810141525958318
#
# Avec 7500.0 itérations, il y a 9.0 coeff de béta mis à 0, et le MSE= 0.27751344402059464
# Norme de béta_hat = 2.602551992547957
#
# Avec 7700.0 itérations, il y a 11.0 coeff de béta mis à 0, et le MSE= 0.27001140525718825
# Norme de béta_hat = 2.557588212197732
#
# Avec 7900.0 itérations, il y a 9.0 coeff de béta mis à 0, et le MSE= 0.2881840738787233
# Norme de béta_hat = 2.4780035899119017
#
# Avec 8100.0 itérations, il y a 11.0 coeff de béta mis à 0, et le MSE= 0.24761733563855595
# Norme de béta_hat = 2.4311314826695103
#
# Avec 8300.0 itérations, il y a 13.0 coeff de béta mis à 0, et le MSE= 0.22770165155568095
# Norme de béta_hat = 2.3935881906894645
#
# Avec 8500.0 itérations, il y a 14.0 coeff de béta mis à 0, et le MSE= 0.2220428636830781
# Norme de béta_hat = 2.346155487008982
#
# Avec 8700.0 itérations, il y a 14.0 coeff de béta mis à 0, et le MSE= 0.21606039250152215
# Norme de béta_hat = 2.2931107996630384
#
# Avec 8900.0 itérations, il y a 17.0 coeff de béta mis à 0, et le MSE= 0.19029570981380006
# Norme de béta_hat = 2.244717195035695
#
# Avec 9100.0 itérations, il y a 14.0 coeff de béta mis à 0, et le MSE= 0.18654896159905607
# Norme de béta_hat = 2.206601302457753
#
# Avec 9300.0 itérations, il y a 13.0 coeff de béta mis à 0, et le MSE= 0.18945544997713165
# Norme de béta_hat = 2.1659260792592216
#
# Avec 9500.0 itérations, il y a 16.0 coeff de béta mis à 0, et le MSE= 0.15638359620857673
# Norme de béta_hat = 2.1055921166229963
#
# Avec 9700.0 itérations, il y a 16.0 coeff de béta mis à 0, et le MSE= 0.15028007706050026
# Norme de béta_hat = 2.053375165195641
#
# Avec 9900.0 itérations, il y a 16.0 coeff de béta mis à 0, et le MSE= 0.1725975486824212
# Norme de béta_hat = 1.9869857108779772
#
# Avec 10100.0 itérations, il y a 18.0 coeff de béta mis à 0, et le MSE= 0.13923123315057706
# Norme de béta_hat = 1.934473254439377
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Pour lambda = 2.0
#
# Avec 500.0 itérations, il y a 0.0 coeff de béta mis à 0, et le MSE= 9.123279059170144
# Norme de béta_hat = 7.0603692989534315
#
# Avec 700.0 itérations, il y a 0.0 coeff de béta mis à 0, et le MSE= 6.122700438281385
# Norme de béta_hat = 6.474595032458795
#
# Avec 900.0 itérations, il y a 1.0 coeff de béta mis à 0, et le MSE= 3.72179426997373
# Norme de béta_hat = 6.002990481585403
#
# Avec 1100.0 itérations, il y a 0.0 coeff de béta mis à 0, et le MSE= 2.953478967609695
# Norme de béta_hat = 5.620266544796391
#
# Avec 1300.0 itérations, il y a 5.0 coeff de béta mis à 0, et le MSE= 2.225525529702735
# Norme de béta_hat = 5.3612999955683325
#
# Avec 1500.0 itérations, il y a 3.0 coeff de béta mis à 0, et le MSE= 2.052516466368694
# Norme de béta_hat = 5.17495322777641
#
# Avec 1700.0 itérations, il y a 3.0 coeff de béta mis à 0, et le MSE= 1.6997272019955745
# Norme de béta_hat = 4.984545331741693
#
# Avec 1900.0 itérations, il y a 4.0 coeff de béta mis à 0, et le MSE= 1.688960488453334
# Norme de béta_hat = 4.793471127482213
#
# Avec 2100.0 itérations, il y a 6.0 coeff de béta mis à 0, et le MSE= 1.457627392411903
# Norme de béta_hat = 4.5914771329349024
#
# Avec 2300.0 itérations, il y a 4.0 coeff de béta mis à 0, et le MSE= 1.243829563706698
# Norme de béta_hat = 4.427513615347207
#
# Avec 2500.0 itérations, il y a 4.0 coeff de béta mis à 0, et le MSE= 1.221844473981097
# Norme de béta_hat = 4.237239482464546
#
# Avec 2700.0 itérations, il y a 8.0 coeff de béta mis à 0, et le MSE= 1.1408282269291068
# Norme de béta_hat = 4.11945876105699
#
# Avec 2900.0 itérations, il y a 8.0 coeff de béta mis à 0, et le MSE= 0.9882595976286944
# Norme de béta_hat = 3.9754051180765027
#
# Avec 3100.0 itérations, il y a 5.0 coeff de béta mis à 0, et le MSE= 0.9933024914454207
# Norme de béta_hat = 3.8593898499517607
#
# Avec 3300.0 itérations, il y a 9.0 coeff de béta mis à 0, et le MSE= 0.9408785691162296
# Norme de béta_hat = 3.747959518720074
#
# Avec 3500.0 itérations, il y a 10.0 coeff de béta mis à 0, et le MSE= 0.7560605731976388
# Norme de béta_hat = 3.614465633879433
#
# Avec 3700.0 itérations, il y a 7.0 coeff de béta mis à 0, et le MSE= 0.64691527242773
# Norme de béta_hat = 3.483980786042426
#
# Avec 3900.0 itérations, il y a 9.0 coeff de béta mis à 0, et le MSE= 0.5351043826662352
# Norme de béta_hat = 3.3568957219445528
#
# Avec 4100.0 itérations, il y a 10.0 coeff de béta mis à 0, et le MSE= 0.5699889530025997
# Norme de béta_hat = 3.2537509337984036
#
# Avec 4300.0 itérations, il y a 10.0 coeff de béta mis à 0, et le MSE= 0.4994693565434527
# Norme de béta_hat = 3.1682774843696295
#
# Avec 4500.0 itérations, il y a 9.0 coeff de béta mis à 0, et le MSE= 0.4592453201824481
# Norme de béta_hat = 3.067245695689662
#
# Avec 4700.0 itérations, il y a 15.0 coeff de béta mis à 0, et le MSE= 0.4160948192073789
# Norme de béta_hat = 2.967146397643129
#
# Avec 4900.0 itérations, il y a 13.0 coeff de béta mis à 0, et le MSE= 0.31550663010145774
# Norme de béta_hat = 2.8379459659523567
#
# Avec 5100.0 itérations, il y a 12.0 coeff de béta mis à 0, et le MSE= 0.2925288954925559
# Norme de béta_hat = 2.753858724231446
#
# Avec 5300.0 itérations, il y a 13.0 coeff de béta mis à 0, et le MSE= 0.3127829216498592
# Norme de béta_hat = 2.640452778251561
#
# Avec 5500.0 itérations, il y a 19.0 coeff de béta mis à 0, et le MSE= 0.29384929251839087
# Norme de béta_hat = 2.553834414727726
#
# Avec 5700.0 itérations, il y a 14.0 coeff de béta mis à 0, et le MSE= 0.2712377366296894
# Norme de béta_hat = 2.466295229603874
#
# Avec 5900.0 itérations, il y a 17.0 coeff de béta mis à 0, et le MSE= 0.26434188671384273
# Norme de béta_hat = 2.4098674298399447
#
# Avec 6100.0 itérations, il y a 20.0 coeff de béta mis à 0, et le MSE= 0.24079475486843538
# Norme de béta_hat = 2.296852501512776
#
# Avec 6300.0 itérations, il y a 24.0 coeff de béta mis à 0, et le MSE= 0.23692755345161595
# Norme de béta_hat = 2.2034877228925924
#
# Avec 6500.0 itérations, il y a 22.0 coeff de béta mis à 0, et le MSE= 0.1639047026206818
# Norme de béta_hat = 2.10527360608078
#
# Avec 6700.0 itérations, il y a 18.0 coeff de béta mis à 0, et le MSE= 0.17292529539592127
# Norme de béta_hat = 2.017069129333927
#
# Avec 6900.0 itérations, il y a 24.0 coeff de béta mis à 0, et le MSE= 0.1479903980282275
# Norme de béta_hat = 1.9024911111443545
#
# Avec 7100.0 itérations, il y a 26.0 coeff de béta mis à 0, et le MSE= 0.13380162616729196
# Norme de béta_hat = 1.8289227690824879
#
# Avec 7300.0 itérations, il y a 33.0 coeff de béta mis à 0, et le MSE= 0.09865481343908875
# Norme de béta_hat = 1.7420683144287976
#
# Avec 7500.0 itérations, il y a 31.0 coeff de béta mis à 0, et le MSE= 0.11126019451577931
# Norme de béta_hat = 1.679384009157791
#
# Avec 7700.0 itérations, il y a 31.0 coeff de béta mis à 0, et le MSE= 0.09750152350986718
# Norme de béta_hat = 1.6226796224737325
#
# Avec 7900.0 itérations, il y a 33.0 coeff de béta mis à 0, et le MSE= 0.09365175252168001
# Norme de béta_hat = 1.5434406338649573
#
# Avec 8100.0 itérations, il y a 40.0 coeff de béta mis à 0, et le MSE= 0.0873526536301695
# Norme de béta_hat = 1.4656339885321652
#
# Avec 8300.0 itérations, il y a 33.0 coeff de béta mis à 0, et le MSE= 0.0634331350855815
# Norme de béta_hat = 1.4260238409347743
#
# Avec 8500.0 itérations, il y a 33.0 coeff de béta mis à 0, et le MSE= 0.056055505666452426
# Norme de béta_hat = 1.3834955228771013
#
# Avec 8700.0 itérations, il y a 40.0 coeff de béta mis à 0, et le MSE= 0.051877099991638045
# Norme de béta_hat = 1.3214520203393247
#
# Avec 8900.0 itérations, il y a 40.0 coeff de béta mis à 0, et le MSE= 0.0472342429788588
# Norme de béta_hat = 1.265449493889232
#
# Avec 9100.0 itérations, il y a 44.0 coeff de béta mis à 0, et le MSE= 0.05218622919242081
# Norme de béta_hat = 1.2190681611612406
#
# Avec 9300.0 itérations, il y a 40.0 coeff de béta mis à 0, et le MSE= 0.05329814602904423
# Norme de béta_hat = 1.16431225887679
#
# Avec 9500.0 itérations, il y a 43.0 coeff de béta mis à 0, et le MSE= 0.0487489696786254
# Norme de béta_hat = 1.1081235939930532
#
# Avec 9700.0 itérations, il y a 44.0 coeff de béta mis à 0, et le MSE= 0.04936755539137221
# Norme de béta_hat = 1.0810541037175896
#
# Avec 9900.0 itérations, il y a 45.0 coeff de béta mis à 0, et le MSE= 0.048852511845885196
# Norme de béta_hat = 1.0566925402905476
#
# Avec 10100.0 itérations, il y a 46.0 coeff de béta mis à 0, et le MSE= 0.047422583609072984
# Norme de béta_hat = 1.0386869576816382

# %%
import matplotlib.pyplot as plt 

for lambda_val in liste_lambdas:
    results_lambda = [r for r in results if r[0] == lambda_val]

    # Extraction des itérations et des MSE
    x_iters = [r[1] for r in results_lambda]  # n_iter
    y_mses  = [r[3] for r in results_lambda]  # mse
    y_norm_beta_hat = [r[4] for r in results_lambda]  # Norme de beta_hat
    y_num_zero= [r[2] for r in results_lambda] 

    # Plot
    plt.figure(figsize=(12, 5))

    ax1 = plt.subplot(1, 2, 1)
    ax1.plot(x_iters, y_mses, linestyle='-', label="MSE")
    ax1.plot(x_iters, y_norm_beta_hat, linestyle='--', label="||B_hat||")
    ax1.set_title(f"MSE et ||B_hat|| (lambda={lambda_val})")
    ax1.set_xlabel("Nombre d'itérations")
    ax1.grid(True)
    ax1.legend()

    ax2 = plt.subplot(1, 2, 2)
    ax2.plot(x_iters, y_num_zero, linestyle='-', color='red', label="Nombre de coeff. nuls")
    ax2.set_title(f"Nombre de coefficients nuls (lambda={lambda_val})")
    ax2.set_xlabel("Nombre d'itérations")
    ax2.grid(True)
    ax2.legend()

    plt.tight_layout()
    plt.show()

# %% [markdown]
# #### Lasso Regression with Sklearn

# %%
from sklearn.linear_model import Lasso, LassoCV, Ridge, RidgeCV

# %% [markdown]
# <font color=darkred>
# Create a np array with several values of the penalty parameter (called $\alpha$ in Python)
# </font>

# %% [markdown]
# <font color=darkred>
# Use the ``fit`` function of sklearn to fit a Lasso model with for each value of $\alpha$.
#
# Store the estimated parameter, the number of zeros in the estimated parameter and the MSE on the test set after each training.
# </font>

# %%
sk_results = []
sk_liste_beta, sk_liste_num_zero, sk_liste_mse = [], [], []
liste_alpha =  [0.001, 0.002, 0.005, 0.01, 0.02, 0.05, 0.1, 0.2, 0.5, 1.0, 2.0]

for alpha_val in liste_alpha :    
    # Create and fit the Lasso model
    lasso = Lasso(alpha=alpha_val, max_iter=100000)
    lasso.fit(X_train, Y_train)
    
    # Get the estimated parameters
    beta_hat = lasso.coef_
    sk_liste_beta.append(lasso.coef_)
    
    # Number of zero coefficients
    num_zero_coefs = np.sum(beta_hat == 0)
    sk_liste_num_zero.append(num_zero_coefs)
    
    # Mean Squared Error on the test set
    Y_pred = lasso.predict(X_test)
    mse = mean_squared_error(Y_test, Y_pred)
    sk_liste_mse.append(mse)
    
    
    # Store the results
    sk_results.append((alpha_val, beta_hat, num_zero_coefs, mse))

# Display the results
#for alpha_val, beta_hat, num_zero_coefs, mse in results:
#    print(f"Pour alpha = {alpha_val}, il y a {num_zero_coefs} coeff de béta mis à 0, et le MSE= {mse}")

# %% [markdown]
# <font color=darkred>
# Display the estimated parameters as a function of the penalty parameter.
# </font>

# %%
nb_features = X_train.shape[1]

my_liste_beta = np.array(my_liste_beta)
my_liste_num_zero_coefs = np.array(my_liste_num_zero_coefs) 
my_liste_mse = np.array(my_liste_mse)

sk_liste_beta = np.array(sk_liste_beta) 
sk_liste_mse = np.array(sk_liste_mse)
sk_liste_num_zero = np.array(sk_liste_num_zero)

# %%
# Graphique coefficients en fonction de 

plt.figure(figsize=(12, 5))

ax1 = plt.subplot(1, 2, 1)
for j in range(nb_features):
    ax1.plot(liste_alpha, sk_liste_beta[:, j], alpha=0.7)

ax1.set_xlabel("Paramètre de pénalité (alpha)")
ax1.set_ylabel("Valeur du j-ième coefficient")
ax1.set_title("Coefficients Lasso en fonction de alpha (Sklearn)")
ax1.set_xscale("log")  # pour un affichage plus lisible quand alpha varie sur plusieurs ordres de grandeur
ax1.grid(True)

ax2 = plt.subplot(1, 2, 2)
for j in range(nb_features):
    ax2.plot(liste_lambdas, my_liste_beta[:, j], alpha=0.7)
ax2.set_xlabel("Paramètre de pénalité (alpha)")
ax2.set_ylabel("Valeur du j-ième coefficient")
ax2.set_title("Coefficients Lasso en fonction de alpha (Mon algo)")
ax2.set_xscale("log")  # pour un affichage plus lisible quand alpha varie sur plusieurs ordres de grandeur
ax2.grid(True)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[45], line 17
#      15 ax2 = plt.subplot(1, 2, 2)
#      16 for j in range(nb_features):
# ---> 17     ax2.plot(liste_lambdas, my_liste_beta[:, j], alpha=0.7)
#      18 ax2.set_xlabel("Paramètre de pénalité (alpha)")
#      19 ax2.set_ylabel("Valeur du j-ième coefficient")
#
# TypeError: list indices must be integers or slices, not tuple

# %% [markdown]
# <font color=darkred>
# Display the number of zero coefficients of the estimated parameter as a function of the penalty parameter.
# </font>

# %%
# Graphique nombre de zéro en fonction de alpha
plt.figure(figsize=(8, 6))

plt.plot(liste_alpha, sk_liste_num_zero, alpha=0.7, label ="Sklearn", color = "red")
plt.plot(liste_lambdas, my_liste_num_zero_coefs, alpha=0.7, label ="Mon algo", color = "blue")

plt.xlabel("Paramètre de pénalité (alpha)")
plt.ylabel("nombre de  coefficient à 0")
plt.title("Evolution du nombre de coefficients à O en fonction de alpha")
plt.xscale("log")
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# <font color=darkred>
# Display the MSE on the test set as a function of the penalty parameter.
# </font>

# %%
# Graphique MSE en fonction de alpha
plt.figure(figsize=(8, 6))

plt.plot(liste_alpha, sk_liste_mse, alpha=0.7, label ="Sklearn", color = "red")
plt.plot(liste_lambdas, my_liste_mse, alpha=0.7, label ="Mon algo", color = "blue")

plt.xlabel("Paramètre de pénalité (alpha)")
plt.ylabel("MSE")
plt.title("Evolution du MSE en fonction de alpha")
plt.xscale("log")
plt.grid(True)
plt.show()
